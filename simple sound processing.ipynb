# %%
import scipy.io.wavfile as wav
import scipy.signal as sig

import matplotlib.pyplot as plt
import numpy as np

import IPython.display as ipd

bach = 'gavotte_en_rondeau.wav'
speech = 'corpus/wav48/p225/p225_006.wav'

# %%
ipd.Audio(speech)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fs, audio_time_orig = wav.read(speech) # actually a stereo file, so contains data for the left and right speaker
fs
# Out:
# 48000

# %%
audio_time_orig = np.array(audio_time_orig)
audio_time_orig[fs // 2:fs // 2 + fs // 10] = 0

# %%
freqs, times, audio_freqs = sig.stft(audio_time_orig, fs) # using just the audio from the left speaker

# %%
std = audio_freqs.std()
audio_freqs[64:] = 0

# %%
audio_freqs[abs(audio_freqs) < 25] = 0

# %%
plt.hist(audio_freqs.reshape(-1), bins=50)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-f55e0936548e> in <module>
# ----> 1 plt.hist(audio_freqs.reshape(-1), bins=50)
#       2 plt.show()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2659         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2660         color=color, label=label, stacked=stacked, normed=normed,
# -> 2661         **({"data": data} if data is not None else {}), **kwargs)
#    2662
#    2663
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6589             # this will automatically overwrite bins,
#    6590             # so that each histogram uses the same bins
# -> 6591             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6592             m = m.astype(float)  # causes problems later if it's an int
#    6593             if mlast is None:
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     772             # The index computation is not guaranteed to give exactly
#     773             # consistent results within ~1 ULP of the bin edges.
# --> 774             decrement = tmp_a < bin_edges[indices]
#     775             indices[decrement] -= 1
#     776             # The last bin includes the right edge. The other bins do not.
#
# IndexError: index 51 is out of bounds for axis 1 with size 51

# %%
def show_spectra(i, size, f, t, z, imax):
    part = slice(i*size, (i+1)*size)
    plt.pcolormesh(t[part], f, np.abs(z[:,part]), vmin=0, vmax=imax)

# %%
def filter_start(freqs, cutoff=25):
    mags = np.abs(freqs).mean(axis=0)
    start = 0
    end = -1
    
    while mags[start] < 25:
        start += 1
    
    while mags[end] < 25:
        end -= 1
    
    return start, end

# %%
times[-515]
# Out:
# 6.397333333333334

# %%
filter_start(audio_freqs)
# Out:
# (592, -515)

# %%
515*2.5
# Out:
# 1287.5

# %%
audio_freqs.shape
# Out:
# (129, 2914)

# %%
import rml.utils.plotting as plot

# %%
plot.plot_list()

# %%
times, audio_time = sig.istft(audio_freqs, fs)

# %%
# not as deep as the original, but I give it a pass, might be a lot better just making it stero again
ipd.Audio(audio_time, rate=fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# original, but only left for a better comparison, I can't tell them apart
